# %% [markdown]
# # Model

# %%
import pandas as pd

train = pd.read_csv('./data/train.csv', index_col='id')
test = pd.read_csv('./data/test.csv', index_col='id')
train.head()
# Out:
#     bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2    nom_3  \
# id
# 0       0      0      0     T     Y  Green   Triangle    Snake  Finland
# 1       0      1      0     T     Y  Green  Trapezoid  Hamster   Russia
# 2       0      0      0     F     Y   Blue  Trapezoid     Lion   Russia
# 3       0      1      0     F     Y    Red  Trapezoid    Snake   Canada
# 4       0      0      0     F     N    Red  Trapezoid     Lion   Canada
#
#        nom_4  ...        nom_9 ord_0        ord_1        ord_2 ord_3  ord_4  \
# id            ...
# 0    Bassoon  ...    2f4cb3d51     2  Grandmaster         Cold     h      D
# 1      Piano  ...    f83c56c21     1  Grandmaster          Hot     a      A
# 2   Theremin  ...    ae6800dd0     1       Expert     Lava Hot     h      R
# 3       Oboe  ...    8270f0d71     1  Grandmaster  Boiling Hot     i      D
# 4       Oboe  ...    b164b72a7     1  Grandmaster     Freezing     a      R
#
#    ord_5 day month target
# id
# 0     kr   2     2      0
# 1     bF   7     8      0
# 2     Jc   7     2      0
# 3     kW   2     1      1
# 4     qP   7     8      0
#
# [5 rows x 24 columns]

# %%
# Feature Engineering 

# From : https://www.kaggle.com/pavelvpster/cat-in-dat-solution-1/

# Use one hot encoding for the features below
ohe_features = ['bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4',
                'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4',
                'ord_0', 'ord_1', 'ord_2', 'ord_3', 'ord_4',
                'day', 'month'] 

# Save the columns that will be used for feature aggregates
fa_features = [
    'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4',
    'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4',
    'nom_5', 'nom_6'
]

train_fa = train[fa_features].copy()
test_fa = test[fa_features].copy()

# Use Label Encoder for the remaining features
le_features = list(set(test.columns) - set(ohe_features))

train_size = len(train)
df = pd.get_dummies(pd.concat([train, test], axis=0, sort=True), 
                    columns=ohe_features, drop_first=True)
train = df[:train_size]
test = df[train_size:].drop('target', axis=1)
del df

# %%
from sklearn.preprocessing import LabelEncoder

def encode_categorial_features_fit(df, columns_to_encode):
    encoders = {}
    for c in columns_to_encode:
        if c in df.columns:
            encoder = LabelEncoder()
            encoder.fit(df[c].astype(str).values)
            encoders[c] = encoder
    return encoders

def encode_categorial_features_transform(df, encoders):
    out = pd.DataFrame(index=df.index)
    for c in encoders.keys():
        if c in df.columns:
            out[c] = encoders[c].transform(df[c].astype(str).values)
    return out

# %%
categorical_features_encoders = encode_categorial_features_fit(
    pd.concat([train, test], join='outer', sort=False), le_features)

# %%
temp = encode_categorial_features_transform(train, categorical_features_encoders)
columns_to_drop = list(set(le_features) & set(train.columns))
train = train.drop(columns_to_drop, axis=1).merge(temp, how='left', left_index=True, right_index=True)

# %%
temp = encode_categorial_features_transform(test, categorical_features_encoders)
columns_to_drop = list(set(le_features) & set(test.columns))
test = test.drop(columns_to_drop, axis=1).merge(temp, how='left', left_index=True, right_index=True)
del temp

# %%
# Target Encoding ( for categorical features with a high cardinality )

from category_encoders import TargetEncoder

te_features = [
    'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9'
]

te = TargetEncoder(cols=te_features, drop_invariant=True, return_df=True, min_samples_leaf=2, smoothing=1.0)
te.fit(train[te_features], train['target'])

temp = te.transform(train[te_features])
columns_to_drop = list(set(te_features) & set(train.columns))
train = train.drop(columns_to_drop, axis=1).merge(temp, how='left', left_index=True, right_index=True)
del temp

temp = te.transform(test[te_features])
columns_to_drop = list(set(te_features) & set(test.columns))
test = test.drop(columns_to_drop, axis=1).merge(temp, how='left', left_index=True, right_index=True)
del temp

# %%
import seaborn as sns

sns.distplot(train['nom_5'])
# Out:
# /Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Feature aggregates


def make_aggregates(df, feature_to_group_by, feature):
    out = pd.DataFrame(index=df.index)
    agg = df.groupby([feature_to_group_by])[feature].value_counts(normalize=True)
    freq = lambda row: agg.loc[row[feature_to_group_by], row[feature]]
    out[feature + '_' + feature_to_group_by + '_freq'] = df.apply(freq, axis=1)
    return out


import itertools


features_to_group_by = ['bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4']
features = ['nom_5', 'nom_6']

for pair in itertools.product(features_to_group_by, features):
    print('Add aggregates of', pair[1], 'by', pair[0])
    
    agg = make_aggregates(train_fa, pair[0], pair[1])
    train = train.merge(agg, how='left', left_index=True, right_index=True)
    del agg
    
    agg = make_aggregates(test_fa, pair[0], pair[1])
    test = test.merge(agg, how='left', left_index=True, right_index=True)
    del agg
# Out:
# Add aggregates of nom_5 by bin_0
# Add aggregates of nom_6 by bin_0
# Add aggregates of nom_5 by bin_1
# Add aggregates of nom_6 by bin_1
# Add aggregates of nom_5 by bin_2
# Add aggregates of nom_6 by bin_2
# Add aggregates of nom_5 by bin_3
# Add aggregates of nom_6 by bin_3
# Add aggregates of nom_5 by bin_4
# Add aggregates of nom_6 by bin_4
# Add aggregates of nom_5 by nom_0
# Add aggregates of nom_6 by nom_0
# Add aggregates of nom_5 by nom_1
# Add aggregates of nom_6 by nom_1
# Add aggregates of nom_5 by nom_2
# Add aggregates of nom_6 by nom_2
# Add aggregates of nom_5 by nom_3
# Add aggregates of nom_6 by nom_3
# Add aggregates of nom_5 by nom_4
# Add aggregates of nom_6 by nom_4

# %%
# Use Auto ML
from azureml.train.automl import AutoMLConfig

# AutoML Configuration
automl_classifier = AutoMLConfig(
    task='classification',
    primary_metric='AUC_weighted',
    max_time_sec=3600,
    iterations=50,
    blacklist_models=['XGBoostClassifier'],
    X=train.drop(columns='target'),
    y=train['target'],
    n_cross_validations=3)
# Out:
# WARNING - Parameter 'max_time_sec' will be deprecated. Use 'iteration_timeout_minutes'

# %%
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace

# Create the workspace using the specified parameters
'''
ws = Workspace.create(name = '',
                      subscription_id = '',
                      resource_group = '', 
                      location = 'West Europe',
                      create_resource_group = False)
ws.get_details()
# write the details of the workspace to a configuration file to the notebook library
ws.write_config()
'''
ws = Workspace.from_config()

# Choose a name for the experiment and specify the project folder.
experiment_name = 'automl-classification'

experiment = Experiment(ws, experiment_name)

run = experiment.submit(automl_classifier, show_output=True)
# Out:
# WARNING - Parameter 'max_time_sec' will be deprecated. Use 'iteration_timeout_minutes'
# Running on local machine
# Parent Run ID: AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1
# Current status: DatasetCrossValidationSplit. Generating CV splits.
#
# ****************************************************************************************************
# DATA GUARDRAILS SUMMARY:
# For more details, use API: run.get_guardrails()
#
# TYPE:         Class Balancing Detection
# STATUS:       PASSED
# DESCRIPTION:  Classes are balanced in the training data.
#
# ****************************************************************************************************
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0   StandardScalerWrapper SGD                      0:00:32       0.8293    0.8293
#          1   StandardScalerWrapper SGD                      0:00:39       0.7967    0.8293
#          2   MinMaxScaler LightGBM                          0:00:39       0.7702    0.8293
#          3   StandardScalerWrapper SGD                      0:00:29       0.8280    0.8293
#          4   StandardScalerWrapper ExtremeRandomTrees       0:02:09       0.7395    0.8293
#          5   MinMaxScaler SGD                               0:00:31       0.8293    0.8293
#          6   StandardScalerWrapper LightGBM                 0:00:38       0.7661    0.8293
#          7   StandardScalerWrapper SGD                      0:00:30       0.8070    0.8293
#          8   MinMaxScaler RandomForest                      0:00:56       0.7366    0.8293
#          9   StandardScalerWrapper SGD                      0:00:42       0.8162    0.8293
#         10   MinMaxScaler SGD                               0:00:34       0.8239    0.8293
#         11   StandardScalerWrapper RandomForest             0:01:19       0.6936    0.8293
#         12   MinMaxScaler SGD                               0:00:32       0.7778    0.8293
#         13   MinMaxScaler RandomForest                      0:00:35       0.7210    0.8293
#         14   MaxAbsScaler LightGBM                          0:00:34       0.7402    0.8293
#         15   MinMaxScaler BernoulliNaiveBayes               0:00:24       0.7318    0.8293
#         16   MinMaxScaler LightGBM                          0:00:49       0.7951    0.8293
#         17   MinMaxScaler ExtremeRandomTrees                0:01:06       0.6911    0.8293
#         18   MinMaxScaler ExtremeRandomTrees                0:01:00       0.7462    0.8293
#         19   MinMaxScaler SGD                               0:00:28       0.8310    0.8310
#         20   StandardScalerWrapper SGD                      0:00:49       0.7381    0.8310
#         21   MaxAbsScaler LightGBM                          0:00:54       0.7770    0.8310
#         22   MinMaxScaler LogisticRegression                0:01:46       0.8333    0.8333
#         23   TruncatedSVDWrapper LogisticRegression         0:05:43       0.8333    0.8333
#         24   StandardScalerWrapper LogisticRegression       0:01:29       0.8332    0.8333
#         25   MinMaxScaler LogisticRegression                0:01:26       0.8317    0.8333
#         26   StandardScalerWrapper LogisticRegression       0:01:30       0.8333    0.8333
#         27   StandardScalerWrapper LogisticRegression       0:19:08       0.8333    0.8333
#         28   StandardScalerWrapper LogisticRegression       0:00:47       0.8333    0.8333
#         29   StandardScalerWrapper LogisticRegression       0:00:56       0.8332    0.8333
#         30   MaxAbsScaler LogisticRegression                0:00:31       0.5000    0.8333
#         31   StandardScalerWrapper LogisticRegression       0:01:02       0.8271    0.8333
#         32   StandardScalerWrapper LogisticRegression       0:01:55       0.8333    0.8333
#         33   RobustScaler LogisticRegression                0:01:06       0.8030    0.8333
#         34
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f760550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f77c790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f764d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f760d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1194f0210>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f75e0d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f760a50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1194fe290>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f790d10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=klz5aRxqEKkTB%2BtZeIJp3eYPEa%2BjeS76epr2pYieu4Y%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# RobustScaler LogisticRegression                0:01:45       0.8333    0.8333
# ERROR: Run AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34 failed with exception "tuple index out of range".
#         35
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x119520fd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/env_dependencies.json?sv=2018-11-09&sr=b&sig=2m1vcRwirtWqVObYQXoQU300Joey1tmTk2yM95ogdd0%3D&st=2019-10-09T22%3A21%3A42Z&se=2019-10-10T22%3A31%3A42Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f798cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_34/outputs/conda_env_v_1_0_0.yml?sv=2018-11-09&sr=b&sig=TcXg6BBxRmzU%2Fscg8QGIL0JZXFWqMXlxFoJhwEL9TP0%3D&st=2019-10-09T22%3A21%3A45Z&se=2019-10-10T22%3A31%3A45Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1194fe390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/conda_env_v_1_0_0.yml?sv=2018-11-09&sr=b&sig=c8S0HRSgq86QBQwJPb2stCnAMgU8UdafKsEtVm8AYGI%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1194fefd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/env_dependencies.json?sv=2018-11-09&sr=b&sig=wTLk5lBl%2BztL8FrSlBTy1b7AElbCUKtDqe%2FyrvpaosE%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x119499610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=p231mVKwGeB%2BsOCtcM1YV0xgP%2BwhaZYSopD1OU2hVZc%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x119515110>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/model.pkl?sv=2018-11-09&sr=b&sig=y03%2B0W1r31SGZp5hLLR%2BNzMmrjQYJ%2Bo%2Fnec2ACS%2BNCc%3D&st=2019-10-09T22%3A23%3A12Z&se=2019-10-10T22%3A33%3A12Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1194f0b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/conda_env_v_1_0_0.yml?sv=2018-11-09&sr=b&sig=c8S0HRSgq86QBQwJPb2stCnAMgU8UdafKsEtVm8AYGI%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x119515410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=p231mVKwGeB%2BsOCtcM1YV0xgP%2BwhaZYSopD1OU2hVZc%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x119515a10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/conda_env_v_1_0_0.yml?sv=2018-11-09&sr=b&sig=c8S0HRSgq86QBQwJPb2stCnAMgU8UdafKsEtVm8AYGI%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1193c1210>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=p231mVKwGeB%2BsOCtcM1YV0xgP%2BwhaZYSopD1OU2hVZc%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# RobustScaler LogisticRegression                0:00:52       0.8208    0.8333
# ERROR: Run AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35 failed with exception "tuple index out of range".
#         36
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1194f0e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=p231mVKwGeB%2BsOCtcM1YV0xgP%2BwhaZYSopD1OU2hVZc%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb1c90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=p231mVKwGeB%2BsOCtcM1YV0xgP%2BwhaZYSopD1OU2hVZc%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb1550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_35/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=p231mVKwGeB%2BsOCtcM1YV0xgP%2BwhaZYSopD1OU2hVZc%3D&st=2019-10-09T22%3A23%3A09Z&se=2019-10-10T22%3A33%3A09Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
#                                                0:00:44          nan    0.8333
#         37                                                  0:00:18          nan    0.8333
#         38                                                  0:00:35          nan    0.8333
#         39
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb4e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/env_dependencies.json?sv=2018-11-09&sr=b&sig=KwPG7mb1wjKIak8YsK03Owqve1KafVwFRg50QXFMWls%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb4e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=aKnzzISgHhlDbuL5L%2BmyFTzS9uAhq964PYS4xLmhkf0%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel/iostream.py", line 97, in _event_pipe
#     event_pipe = self._local.event_pipe
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/logging/__init__.py", line 1028, in emit
#     stream.write(msg + self.terminator)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel/iostream.py", line 402, in write
#     self.pub_thread.schedule(lambda : self._buffer.write(string))
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel/iostream.py", line 205, in schedule
#     self._event_pipe.send(b'')
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel/iostream.py", line 101, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/zmq/sugar/context.py", line 204, in socket
#     s = self._socket_class(self, socket_type, **kwargs)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/zmq/sugar/socket.py", line 59, in __init__
#     super(Socket, self).__init__(*a, **kw)
#   File "zmq/backend/cython/socket.pyx", line 328, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Call stack:
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/threading.py", line 890, in _bootstrap
#     self._bootstrap_inner()
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/concurrent/futures/thread.py", line 80, in _worker
#     work_item.run()
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/azureml/_vendor/azure_storage/blob/_upload_chunking.py", line 210, in process_chunk
#     return self._upload_chunk_with_progress(chunk_offset, chunk_bytes)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/azureml/_vendor/azure_storage/blob/_upload_chunking.py", line 224, in _upload_chunk_with_progress
#     range_id = self._upload_chunk(chunk_offset, chunk_data)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/azureml/_vendor/azure_storage/blob/_upload_chunking.py", line 269, in _upload_chunk
#     timeout=self.timeout,
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/azureml/_vendor/azure_storage/blob/blockblobservice.py", line 1013, in _put_block
#     self._perform_request(request)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/azureml/_vendor/azure_storage/common/storageclient.py", line 269, in _perform_request
#     response = self._httpclient.perform_request(request)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/azureml/_vendor/azure_storage/common/_http/httpclient.py", line 92, in perform_request
#     proxies=self.proxies)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/houssam/anaconda3/envs/myenv/lib/python3.7/site-packages/urllib3/connectionpool.py", line 748, in urlopen
#     url,
# Message: "Retrying (%r) after connection broken by '%r': %s"
# Arguments: (Retry(total=2, connect=None, read=None, redirect=None, status=None), NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb4e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'), '/azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=aKnzzISgHhlDbuL5L%2BmyFTzS9uAhq964PYS4xLmhkf0%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30')
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb4610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/pipeline_graph.json?sv=2018-11-09&sr=b&sig=rdGySdlKibC%2BxEIqStmUI1Kn6ucBZCSKWVZbCxR6Opc%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11b0895d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/model.pkl?sv=2018-11-09&sr=b&sig=NDWCBhn%2BGY2JNmpWRws1aHyAIzMfaxmD9yy8q%2FXA6eA%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11edb1fd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/conda_env_v_1_0_0.yml?sv=2018-11-09&sr=b&sig=YmuCaEw8NfCHAF3RZouw4CBMbOhTY5cyWUaKBNwehew%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# --- Logging error ---
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x119470410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=aKnzzISgHhlDbuL5L%2BmyFTzS9uAhq964PYS4xLmhkf0%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f77c510>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/model.pkl?sv=2018-11-09&sr=b&sig=NDWCBhn%2BGY2JNmpWRws1aHyAIzMfaxmD9yy8q%2FXA6eA%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f764c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/scoring_file_v_1_0_0.py?sv=2018-11-09&sr=b&sig=aKnzzISgHhlDbuL5L%2BmyFTzS9uAhq964PYS4xLmhkf0%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12f770c10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /azureml/ExperimentRun/dcid.AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39/outputs/model.pkl?sv=2018-11-09&sr=b&sig=NDWCBhn%2BGY2JNmpWRws1aHyAIzMfaxmD9yy8q%2FXA6eA%3D&st=2019-10-09T22%3A25%3A52Z&se=2019-10-10T22%3A35%3A52Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30
# MaxAbsScaler LogisticRegression                0:01:01       0.8333    0.8333
# ERROR: Run AutoML_c8b5c907-57e1-451f-ab5c-84e946a73ae1_39 failed with exception "tuple index out of range".
#         40                                                  0:00:07          nan    0.8333
#         41                                                  0:00:34          nan    0.8333
#         42                                                  0:00:24          nan    0.8333
#         43                                                  0:00:12          nan    0.8333
#         44                                                  0:00:10          nan    0.8333
#         45                                                  0:00:05          nan    0.8333
#         46                                                  0:00:03          nan    0.8333
#         47                                                  0:00:14          nan    0.8333
# Received interrupt. Returning now.

# %%
best_run, fitted_model = run.get_output()

# %%
# Predict on the Test set
y_pred = fitted_model.predict(test)

# %%
# Create and save submission DF
pred_df = pd.DataFrame({'id': test.index, 'target':y_pred})
pred_df.to_csv('data/submit_automl.csv', index=False)
